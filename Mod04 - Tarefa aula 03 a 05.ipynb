# %% [markdown]
# # Tarefa 02
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os tutores
# - Divirta-se :)
#
# ## Exercício 1: Vestibular
#
# Considere que a os dados gerados na célula abaixo contêm o número de acertos de 100 alunos em um vestibular para um curso de exatas, divididas pelos respectivos assuntos. Considere que cada assunto possui um número de questões conforme a tabela abaixo:
#
# | assunto | número de questões |
# |:---:|:---:|
# | Matemática | 24 |
# | Português | 18 |
# | Geografia | 8 |
# | Inglês | 8 |
# | História | 8 |
# | Física | 12 |
# | Química | 12 |
#
# Usando os comandos de operações com DataFrames que você aprendeu na Aula 03, calcule:
#
# 1. (operações com escalar) Calcule o percentual de acerto dos alunos por assunto.
# 2. (operações entre *DataFrames) Calcule o total de acertos de cada aluno.
# 3. Calcule o porcentual geral de cada aluno.
# 4. Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior que 45?

# %%
import pandas as pd
import numpy as np

np.random.seed(42)
df_mat = pd.DataFrame(np.random.randint(24, size=(100, 1)), columns=['Qt_acertos'])

df_por = pd.DataFrame(np.random.randint(18, size=(100, 1)), columns=['Qt_acertos'])

df_geo = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_ing = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_his = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_fis = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

df_qui = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

# %%
# 1) Seu código aqui

per_acertos_mat = (df_mat/24)*100

per_acertos_por = (df_por/18)*100

per_acertos_geo = (df_por/8)*100

per_acertos_ing = (df_por/8)*100

per_acertos_his = (df_por/8)*100

per_acertos_fis = (df_por/12)*100

per_acertos_qui = (df_por/12)*100

# %%
# 2) Seu código aqui

total_de_acertos = df_mat + df_por + df_geo + df_ing + df_his + df_fis + df_qui

total_de_acertos
# Out:
#     Qt_acertos
# 0           35
# 1           48
# 2           50
# 3           32
# 4           30
# ..         ...
# 95          34
# 96          27
# 97          40
# 98          40
# 99          42
#
# [100 rows x 1 columns]

# %%
# 3) Seu código aqui

per_acertos = ((total_de_acertos/90)*100).round(2)

per_acertos
# Out:
#     Qt_acertos
# 0        38.89
# 1        53.33
# 2        55.56
# 3        35.56
# 4        33.33
# ..         ...
# 95       37.78
# 96       30.00
# 97       44.44
# 98       44.44
# 99       46.67
#
# [100 rows x 1 columns]

# %%
# 4) Seu código aqui

acertos_maior_45 = total_de_acertos['Qt_acertos'] > 45

acertos_maior_45.sum()
# Out:
# 31

# %% [markdown]
# ## 2) Vestibular II
#
# Ainda sobre o mesmo banco de dados:
#
# 1. Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. Monte um novo *DataFrame* com os alunos desqualificados por este critério.
# 2. Quantos são esses alunos?
# 3. Qual a média desses alunos em história e geografia?
# 4. Monte um *DataFrame* com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.

# %%
# 1) Seu código aqui

# Transformando em um único DataFrame

#Matemática

df_mat['Matemática'] = df_mat['Qt_acertos']

df_mat.drop(['Qt_acertos'], axis='columns', inplace = True)

#Português

df_por['Português'] = df_por['Qt_acertos']

df_por.drop(['Qt_acertos'], axis='columns', inplace = True)

#Geografia

df_geo['Geografia'] = df_geo['Qt_acertos']

df_geo.drop(['Qt_acertos'], axis='columns', inplace = True)

# Inglês

df_ing['Inglês'] = df_ing['Qt_acertos']

df_ing.drop(['Qt_acertos'], axis='columns', inplace = True)

# História

df_his['História'] = df_his['Qt_acertos']

df_his.drop(['Qt_acertos'], axis='columns', inplace = True)

# Física

df_fis['Física'] = df_fis['Qt_acertos']

df_fis.drop(['Qt_acertos'], axis='columns', inplace = True)

# Química

df_qui['Química'] = df_qui['Qt_acertos']

df_qui.drop(['Qt_acertos'], axis='columns', inplace = True)

# %%
df_concat = pd.concat([df_mat, df_por, df_geo, df_ing, df_his, df_fis, df_qui], axis=1, join='outer')

df_concat
# Out:
#     Matemática  Português  Geografia  Inglês  História  Física  Química
# 0            6          7          7       3         1       8        3
# 1           19         10          0       0         0      11        8
# 2           14         16          0       5         7       4        4
# 3           10          7          3       4         0       0        8
# 4            7          2          2       7         0       9        3
# ..         ...        ...        ...     ...       ...     ...      ...
# 95           6          4          7       1         4       9        3
# 96           8          1          4       6         1       4        3
# 97          23          5          0       2         4       1        5
# 98           0         10          3       1         5      10       11
# 99          11         15          0       1         6       7        2
#
# [100 rows x 7 columns]

# %%
# 1) Seu código aqui

df_desc_mat = df_concat[df_concat['Matemática'] == 0]
          
df_desc_fis = df_concat[df_concat['Física'] == 0]
          
df_desc_qui = df_concat[df_concat['Química'] == 0]

# %%
# Dataframe com os desqualificados

df_desclassificados = df_concat[(df_concat['Matemática'] == 0).__or__ (df_concat['Física'] == 0).__or__(df_concat['Química'] == 0)]
          

df_desclassificados
# Out:
#     Matemática  Português  Geografia  Inglês  História  Física  Química
# 3           10          7          3       4         0       0        8
# 6            6          0          7       7         5       0        4
# 10          10          8          3       2         1       7        0
# 12          20          8          3       7         1       0        3
# 14           7         11          1       7         1       4        0
# 20          23         11          6       5         6       2        0
# 25           0          4          7       4         0       4        8
# 26          11         14          6       2         7       0        0
# 27          21         13          1       5         7       3        0
# 33          14          8          0       5         6       6        0
# 35          11         14          6       3         3       0       11
# 49           8          1          1       0         1       0        8
# ...

# %%
# 2) Seu código aqui

df_desclassificados.shape[0]
# Out:
# 23

# %%
# 3) Seu código aqui

# Média em história

df_desclassificados['História'].mean()
# Out:
# 3.4347826086956523

# %%
# Média em geografia

df_desclassificados['Geografia'].mean()
# Out:
# 3.217391304347826

# %%
# 4) Dataframe com os desqualificados

df_class = df_concat[(df_concat['Matemática'] > 0) & (df_concat['Física'] > 0) & (df_concat['Química'] > 0)]
          
df_class
# Out:
#     Matemática  Português  Geografia  Inglês  História  Física  Química
# 0            6          7          7       3         1       8        3
# 1           19         10          0       0         0      11        8
# 2           14         16          0       5         7       4        4
# 4            7          2          2       7         0       9        3
# 5           20          2          5       3         2       9        9
# ..         ...        ...        ...     ...       ...     ...      ...
# 93          12         16          5       5         6       6        6
# 95           6          4          7       1         4       9        3
# 96           8          1          4       6         1       4        3
# 97          23          5          0       2         4       1        5
# 99          11         15          0       1         6       7        2
#
# [77 rows x 7 columns]

# %% [markdown]
# ## 3) Vacinações no Acre
# Vamos trabalhar agora com a base de vacinações no Acre. Para facilitar a sua vida, copiamos o link do arquivo na célula abaixo.
#
# 1. Quantas vacinas estão registradas nessa base?
# 2. Quantos pacientes foram vacinados? (considere um paciente para cada valor único de ```paciente_id```)
# 3. Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. Receba os valores do campo com o método ```.unique()```.
# 4. Quantos pacientes com menos de 18 anos foram vacinados?
# 5. Quantos estabelecimentos aplicaram vacina no Acre?

# %%
arquivo = 'https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SIPNI/COVID/uf/uf%3DAC/part-00000-93d483f4-9b66-4fd6-a7c5-d617a9d03b7b.c000.csv'

# %%
df_vacinas = pd.read_csv('https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SIPNI/COVID/uf/uf%3DAC/part-00000-93d483f4-9b66-4fd6-a7c5-d617a9d03b7b.c000.csv', sep = ';')

df_vacinas.head()
# Out:
# C:\Users\luisl\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                                  document_id  \
# 0  4ff28e0e-02df-4947-a402-7f6c0993d6c9-i0b0
# 1  a0a56c4b-7252-4098-956f-955759ed500a-i0b0
# 2  8c757ef8-e1a1-4658-ab07-ee7b9865a1fa-i0b0
# 3  a0baa356-deba-4d49-a54c-141141b4b301-i0b0
# 4  dcf75e5a-fd0f-4cc6-bb98-36c958e156da-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  d025ffced1c17dd83e7ed9615e109b513225afcaf6f7ea...              77
# 1  8c165ecfd823d33ce4d862926a229c17f127b112505697...              15
# 2  f6cc130d3ef580e689f97cfe76a6e6124d91b7e928f9ab...              20
# 3  7a08ec40546abc0f95fdfa4ec1efb22f3f775d7271417d...              47
# 4  5aafa70333fc3942d6b51c6bd586cd64bec8103f44c0a5...              47
#
# ...

# %%
df_vacinas.shape
# Out:
# (413793, 32)

# %%
# 1) Sua solução aqui

df_vacinas.shape[0]
# Out:
# 413793

# %%
# 2) 

df_vacinas['paciente_id'].nunique()
# Out:
# 337037

# %%
# 3) 

df_vacinas['vacina_descricao_dose'].unique()
# Out:
# array(['2ª Dose', '1ª Dose', 'Reforço', 'Dose', 'Dose Adicional'],
#       dtype=object)

# %%
vacinados_1_dose = df_vacinas[df_vacinas['vacina_descricao_dose'] == '1ª Dose']

vacinados_1_dose['paciente_id'].nunique()
# Out:
# 202702

# %%
# 3) solução alternativa

# %%
# 4) 

vacinados_menor_18 = df_vacinas[df_vacinas['paciente_idade'] < 18]

vacinados_menor_18['paciente_id'].nunique()
# Out:
# 44497

# %%
# 5) 

df_vacinas['estabelecimento_razaoSocial'].nunique()
# Out:
# 46

# %% [markdown]
# ## 4) Vacinação II
# Gere um *DataFrame* que contenha somente os estabelecimentos que aplicaram vcinas a menores de 18 anos. Nesse *DataFrame* devem conter somente os dados dos estabelecimentos, mais uma coluna sendo a quantidade de vacinas que o estabelecimento aplicou a menores de 18 anos.
#
# 1. crie uma cópia do *DataFrame* original, contendo somente os registros de vacinas realizadas a menores de 18 anos.
# 2. crie uma lista das colunas desse *DataFrame* com o atributo de *DataFrame* **.columns()**
# 3. Nesse *DataFrame* faça uma contagem do campo ```vacina_categoria_nome```.
# 3. a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, faça uma lista com esses valores.
# 4. usando o método *.loc*, selecione somente essas variáveis
# 5. Aplique o método **.drop_duplicates** e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento

# %%
# DataFrame contendo somente os dados dos estabelecimentos, 
# mais uma coluna sendo a quantidade de vacinas que o estabelecimento aplicou a menores de 18 anos

def vacinas_menores_18_bool(x):
    if x < 18:
        return True
    else:
        return False

df_vacinas['paciente_idade_bool_menor_18'] = df_vacinas['paciente_idade'].apply(vacinas_menores_18_bool)

df_vacinas[['paciente_idade', 'estabelecimento_razaoSocial', 'paciente_idade_bool_menor_18']]
# Out:
#         paciente_idade              estabelecimento_razaoSocial  \
# 0                   77   PREFEITURA MUNICIPAL DE EPITACIOLANDIA
# 1                   15       PREFEITURA MUNICIPAL DE RIO BRANCO
# 2                   20       PREFEITURA MUNICIPAL DE RIO BRANCO
# 3                   47            SECRETARIA MUNICIPAL DE SAUDE
# 4                   47         PREFEITURA MUNICIPAL DE TARAUACA
# ...                ...                                      ...
# 413788              63         PREFEITURA MUNICIPAL DE TARAUACA
# 413789              62       PREFEITURA MUNICIPAL DE RIO BRANCO
# 413790              20  PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 413791              45       PREFEITURA MUNICIPAL DE RIO BRANCO
# 413792              21       PREFEITURA MUNICIPAL DE RIO BRANCO
#
#         paciente_idade_bool_menor_18
# 0                              False
# 1                               True
# 2                              False
# 3                              False
# ...

# %%
df_vacinas['paciente_idade_bool_menor_18'].groupby(df_vacinas['estabelecimento_razaoSocial']).sum()
# Out:
# estabelecimento_razaoSocial
# 61 BIS                                                              0
# A M COMERCIO E REPRESENTACOES LTDA                                  0
# CENTRO DE DIAGNOSTICOS CITOLAB LTDA                                 0
# DISTRITO SANITARIO ESPECIAL DE SAUDE INDIGENA ALTO RIO PURUS        8
# DISTRITO SANITARIO ESPECIAL INDIGENA ALTO JURUA                   142
# DISTRITO SANITARIO ESPECIAL INDIGENA ALTO RIO JURUA               302
# DISTRITO SANITARIO ESPECIAL INDIGENA ALTO RIO PURUS                 0
# K M OLIVEIRA EIRELI                                                 0
# LUIZ AUGUSTO NO BATISTA                                             0
# MINISTERIO DA SAUDE                                                20
# MUNICIPIO DE MANCIO LIMA                                           13
# MUNICIPIO DE MARECHAL THAUMATURGO                                  13
# MUNICIPIO DE PORTO WALTER                                          47
# ...

# %%
df_vacinas['soma_vacinas_menor_18'] = df_vacinas['paciente_idade_bool_menor_18'].groupby(
    df_vacinas['estabelecimento_razaoSocial']).transform(lambda x: x.sum())

df_vacinas.head()
# Out:
#                                  document_id  \
# 0  4ff28e0e-02df-4947-a402-7f6c0993d6c9-i0b0
# 1  a0a56c4b-7252-4098-956f-955759ed500a-i0b0
# 2  8c757ef8-e1a1-4658-ab07-ee7b9865a1fa-i0b0
# 3  a0baa356-deba-4d49-a54c-141141b4b301-i0b0
# 4  dcf75e5a-fd0f-4cc6-bb98-36c958e156da-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  d025ffced1c17dd83e7ed9615e109b513225afcaf6f7ea...              77
# 1  8c165ecfd823d33ce4d862926a229c17f127b112505697...              15
# 2  f6cc130d3ef580e689f97cfe76a6e6124d91b7e928f9ab...              20
# 3  7a08ec40546abc0f95fdfa4ec1efb22f3f775d7271417d...              47
# 4  5aafa70333fc3942d6b51c6bd586cd64bec8103f44c0a5...              47
#
#   paciente_dataNascimento paciente_enumSexoBiologico  paciente_racaCor_codigo  \
# 0              1943-10-27                          M                        3
# 1              2006-01-10                          M                        3
# ...

# %%
df_vacinas_new = df_vacinas[['estabelecimento_razaoSocial', 'soma_vacinas_menor_18']]

df_vacinas_new
# Out:
#                     estabelecimento_razaoSocial  soma_vacinas_menor_18
# 0        PREFEITURA MUNICIPAL DE EPITACIOLANDIA                    899
# 1            PREFEITURA MUNICIPAL DE RIO BRANCO                  21801
# 2            PREFEITURA MUNICIPAL DE RIO BRANCO                  21801
# 3                 SECRETARIA MUNICIPAL DE SAUDE                   1101
# 4              PREFEITURA MUNICIPAL DE TARAUACA                   2634
# ...                                         ...                    ...
# 413788         PREFEITURA MUNICIPAL DE TARAUACA                   2634
# 413789       PREFEITURA MUNICIPAL DE RIO BRANCO                  21801
# 413790  PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL                   5662
# 413791       PREFEITURA MUNICIPAL DE RIO BRANCO                  21801
# 413792       PREFEITURA MUNICIPAL DE RIO BRANCO                  21801
#
# [413793 rows x 2 columns]

# %%
df_vacinas_new = df_vacinas_new.drop_duplicates()

df_vacinas_new
# Out:
#                               estabelecimento_razaoSocial  \
# 0                  PREFEITURA MUNICIPAL DE EPITACIOLANDIA
# 1                      PREFEITURA MUNICIPAL DE RIO BRANCO
# 3                           SECRETARIA MUNICIPAL DE SAUDE
# 4                        PREFEITURA MUNICIPAL DE TARAUACA
# 6                   PREFEITURA MUNICIPAL DE MANUEL URBANO
# 7                 PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 11                     PREFEITURA MUNICIPAL DE PORTO ACRE
# 17                      PREFEITURA MUNICIPAL DE BRASILEIA
# 18      DISTRITO SANITARIO ESPECIAL INDIGENA ALTO RIO ...
# 32                PREFEITURA MUNICIPAL DE RODRIGUES ALVES
# 33                         PREFEITURA MUNICIPAL DE JORDAO
# 34               PREFEITURA MUNICIPAL DE SENADOR GUIOMARD
# 38                       PREFEITURA MUNICIPAL DE CAPIXABA
# 46                     PREFEITURA MUNICIPAL DE ACRELANDIA
# 53                 PREFEITURA MUNICIPAL DE SENA MADUREIRA
# ...

# %%
df_vacinas_new.shape
# Out:
# (46, 2)

# %%
# 1) 

df_vacinas_menores_18 = df_vacinas[df_vacinas['paciente_idade'] < 18]

df_vacinas_menores_18
# Out:
#                                       document_id  \
# 1       a0a56c4b-7252-4098-956f-955759ed500a-i0b0
# 7       a0bf2424-2010-47b5-9bd2-71df68785462-i0b0
# 9       a0c1d3b2-196c-4820-a169-33ef6d645c9f-i0b0
# 20      cf0aa0bc-0319-4b78-9207-6058607a15a0-i0b0
# 27      a207633b-f07f-4d13-8f15-66918475deec-i0b0
# ...                                           ...
# 413725  8b51d92e-e262-4038-b68c-ffbee4fd78a4-i0b0
# 413736  8d41849d-b039-4d49-a3e9-1d945ec801f8-i0b0
# 413742  8db7e55d-670c-4c56-ac76-e40b32e8c6fb-i0b0
# 413762  92f34126-3c53-4206-b999-dea4e7419264-i0b0
# 413780  95eec920-502c-4a9c-9ed6-19ad3c36584a-i0b0
#
#                                               paciente_id  paciente_idade  \
# 1       8c165ecfd823d33ce4d862926a229c17f127b112505697...              15
# 7       93ce92465d016f68eac3c7e461b604a5c9b5b5e63c3ade...              17
# 9       361b4594f675d4b49d4ee99115b295da2896217f7a5276...              16
# ...

# %%
# 2)

df_vacinas_colunas = df_vacinas.columns

df_vacinas_colunas
# Out:
# Index(['document_id', 'paciente_id', 'paciente_idade',
#        'paciente_dataNascimento', 'paciente_enumSexoBiologico',
#        'paciente_racaCor_codigo', 'paciente_racaCor_valor',
#        'paciente_endereco_coIbgeMunicipio', 'paciente_endereco_coPais',
#        'paciente_endereco_nmMunicipio', 'paciente_endereco_nmPais',
#        'paciente_endereco_uf', 'paciente_endereco_cep',
#        'paciente_nacionalidade_enumNacionalidade', 'estabelecimento_valor',
#        'estabelecimento_razaoSocial', 'estalecimento_noFantasia',
#        'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
#        'estabelecimento_uf', 'vacina_grupoAtendimento_codigo',
#        'vacina_grupoAtendimento_nome', 'vacina_categoria_codigo',
#        'vacina_categoria_nome', 'vacina_lote', 'vacina_fabricante_nome',
#        'vacina_fabricante_referencia', 'vacina_dataAplicacao',
#        'vacina_descricao_dose', 'vacina_codigo', 'vacina_nome',
# ...

# %%
# 3) 

df_vacinas_menores_18['vacina_categoria_nome'].count()
# Out:
# 46201
